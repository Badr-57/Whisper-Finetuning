# %%
# !pip install --upgrade pip

# %%
# !pip install -r requirements.txt

# %%
# !pip install soundfile scipy gdown

# %%
# !pip install -U openai-whisper

# %%
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist \
# nvidia-dali-cuda110==1.28.0  # Match CUDA version

# %%
#!git clone https://github.com/NVIDIA/apex
# !cd "apex"
# !pip install -v --disable-pip-version-check --no-cache-dir --no-build-isolation --config-settings "--build-option=--cpp_ext" --config-settings "--build-option=--cuda_ext" ./

# %%
# !pip install apex

# %%
# !python run_finetuning.py --help

# %%
# !python calculate_metric.py --help

# %%
#from apex.optimizers import FusedAdam
#
#try:
#    print("FusedAdam available:", FusedAdam is not None)
#except ImportError:
#    print("FusedAdam not available")

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import whisper
# whisper.available_models()

# %%
file_id = '1eMNvye81kq-W_1oKaZNsopmW-rrpmuzy'  # Replace with your file ID from shareable link
# !gdown --id $file_id

# %%
# !python create_data.py --audio-dir "train/audio" --transcript-dir "train/subs" --language ar --max-prompt-length 90 --max-tokens-length 340 --output train.json

# %%
# !python create_data.py --audio-dir "dev/audio" --transcript-dir "dev/subs" --language ar --max-prompt-length 90 --max-tokens-length 340 --output dev.json

# %%
import gc
gc.collect()  # Collects garbage from all generations
# Out:
# 0

# %%
import torch
if torch.cuda.is_available():
    torch.cuda.empty_cache()  # Frees PyTorch's memory pool

# %%
# !python run_finetuning.py \
--train-json "train.json" \
--dev-json "dev.json" \
--batch-size 6 \
--dev-batch-size 16 \
--device "cuda" \
--prompt-use-rate 0.3 \
--no-timestamps-rate 0.0 \
--save-dir "Checkpoints" \
--model "large-v3-turbo" \
--lr 5e-5 \
--accum-grad-steps 1 \
--warmup-steps 630 \
--train-steps 6300 \
--eval-steps 630 \
--save-all-checkpoints \
--use-adam-8bit \
--use-amp \
--gradient-checkpointing
# Out:
# Truncated record /Whisper-FT/dump/خطر الكلب ｜ الدحيح/961091.pt from 444 to 443 tokens
# Truncated record /Whisper-FT/dump/رحلة اليقين ٥٣： الدليل العلمي على وجود الملائكة ｜ الدكتورإياد قنيبي/976919.pt from 486 to 443 tokens
# Truncated record /Whisper-FT/dump/＂بَس تربية؟＂/134830.pt from 446 to 443 tokens
# Truncated record /Whisper-FT/dump/＂بَس تربية؟＂/190474.pt from 450 to 443 tokens
# Truncated record /Whisper-FT/dump/＂بَس تربية؟＂/217709.pt from 466 to 443 tokens
# 100%|███████████████████████████████████████████| 44/44 [00:36<00:00,  1.20it/s]
# Initial loss: 5.6522
# ...
